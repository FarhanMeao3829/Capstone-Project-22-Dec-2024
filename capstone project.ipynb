# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = sns.load_dataset('diamonds')
df.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
df1 = df.drop("cut", axis=1)
df1 = df1.drop("color", axis=1)
df1 = df1.drop("clarity", axis=1)
sns.heatmap(df1.corr(), cmap='bone', annot=True)
# Out:
# <Axes: >

# %%
df1.hist(figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'carat'}>,
#         <Axes: title={'center': 'depth'}>,
#         <Axes: title={'center': 'table'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: title={'center': 'x'}>,
#         <Axes: title={'center': 'y'}>],
#        [<Axes: title={'center': 'z'}>, <Axes: >, <Axes: >]], dtype=object)

# %%
sns.countplot(data=df, x='color', palette='summer')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14436\1278685798.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='color', palette='summer')
# <Axes: xlabel='color', ylabel='count'>

# %%
sns.countplot(data=df, x='carat', palette='RdPu')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14436\3957041168.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='carat', palette='RdPu')
# <Axes: xlabel='carat', ylabel='count'>

# %%
sns.countplot(data=df, x='clarity', palette='YlOrRd')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14436\1350800065.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='clarity', palette='YlOrRd')
# <Axes: xlabel='clarity', ylabel='count'>

# %%
sns.countplot(data=df, x= 'clarity', hue='carat', palette='husl')
# Out:
# <Axes: xlabel='clarity', ylabel='count'>

# %%
sns.countplot(data=df, x='color', hue='clarity', palette='spring')
# Out:
# <Axes: xlabel='color', ylabel='count'>

# %%
sns.pairplot(data=df, hue='clarity', palette='mako')

# %%
sns.countplot(data=df, x='carat', palette='summer')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14436\1214799136.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='carat', palette='summer')
# <Axes: xlabel='carat', ylabel='count'>
